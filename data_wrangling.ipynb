# %%
import pandas as pd

# %%
experiments = pd.read_csv('rag_experiment_results.csv')

# %%
experiments.columns
# Out:
# Index(['index_name', 'alpha', 'similarity_top_k', 'cross_encoder_model',
#        'llm_model_name', 'rerank_top_n', 'llm_provider', 'prompt_template',
#        'faithfulness', 'factual_correctness(mode=f1)',
#        'llm_context_precision_with_reference', 'context_recall',
#        'avg_latency_sec', 'latency_95th_sec'],
#       dtype='object')

# %%
experiments['#experiment'] = 1

# %%
record = {
    'faithfulness': 0.9,
    '#experiment': 2
}

# %%
pd.concat([experiments, pd.DataFrame([record])], ignore_index=True)
# Out:
#                            index_name  alpha  similarity_top_k  \
# 0                  Normal_splitter_hf    0.8               3.0
# 1                  Normal_splitter_hf    0.8               3.0
# 2                  Normal_splitter_hf    0.8               5.0
# 3                  Normal_splitter_hf    0.8               5.0
# 4                  Normal_splitter_hf    0.8              10.0
# ..                                ...    ...               ...
# 144  Custom_splitter_w_context_openai    1.0              10.0
# 145  Custom_splitter_w_context_openai    1.0              10.0
# 146  Custom_splitter_w_context_openai    1.0              15.0
# 147  Custom_splitter_w_context_openai    1.0              15.0
# 148                               NaN    NaN               NaN
#
#                       cross_encoder_model llm_model_name  rerank_top_n  \
# 0                                     NaN    gpt-4o-mini           3.0
# ...

# %%
experiments
# Out:
#                            index_name  alpha  similarity_top_k  \
# 0                  Normal_splitter_hf    0.8                 3
# 1                  Normal_splitter_hf    0.8                 3
# 2                  Normal_splitter_hf    0.8                 5
# 3                  Normal_splitter_hf    0.8                 5
# 4                  Normal_splitter_hf    0.8                10
# ..                                ...    ...               ...
# 143  Custom_splitter_w_context_openai    1.0                 5
# 144  Custom_splitter_w_context_openai    1.0                10
# 145  Custom_splitter_w_context_openai    1.0                10
# 146  Custom_splitter_w_context_openai    1.0                15
# 147  Custom_splitter_w_context_openai    1.0                15
#
#                       cross_encoder_model llm_model_name  rerank_top_n  \
# 0                                     NaN    gpt-4o-mini             3
# ...
