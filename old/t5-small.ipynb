# %% [markdown]
# # Fine-tuning Pretrained T5-small model with raw text

# %% [markdown]
# ## Dependecies

# %%
from datasets import Dataset
import re
from transformers import Trainer, TrainingArguments

# %% [markdown]
# ## Cleaning

# %%
RAW_TXT_PATH = "./dataset/webscrape/raw.txt"

# %%
raw_txt = open(RAW_TXT_PATH, "r").read()

# %%
raw_txt
# Out:
# '\n\n\n\n\nVisa/Consular Services\n\n2025/1/9\n\n\nJapanese\n\n\n\nVISA\n\nImportant Notice\n1. Digitization of "Certificate of Eligibility (COE)"\n\xa0 From 17th March, Japan Immigration accepts application for digitized COE. For details, please see this.\n\n2. Acceptance of Photocopy of Japanese Documents\xa0\n\xa0From 17th March, we accept photocopy of documents issued/prepared in Japan instead of the original. For details, please see this.\xa0\n\n3. Advanced procedures for Customs, Immigration and Quarantine\n1. From 29th April 2023, all entrants/returnees to Japan do not need to submit a valid vaccination certificate nor a negative certificate of COVID-19.\n2. Please use “Visit Japan Web” for smooth Immigration and Customs procedures when traveling to Japan.\n\xa0\nHow to Apply\n\xa0\n\n\nInquiries Concerning Visa\xa0\nGeneral Information\nList of Accredited Agencies\nFAQs on Japan Visa\nExtension of Re-entry Permit\nVisa Fee Exemption for Foreigners Visiting Three Tohoku Prefectures\n\n\n\n\n\nTypes of Visa and Requirements\n\nChoose one of visas below suitable for purpose of your travel to check your requirements and then see\xa0“IMPORTANT NOTE ON THE DOCUMENT SUBMISSION”.\n\n1. Temporary Visitor (for stay within 90 days at maximum)\n(1)\xa0Tourism*Due to the rapid increase in the number of visitors from the Philippines, examination of visa applications for tourism purposes, may take several weeks longer than the standard processing time. Therefore, we highly recommend for applicants to please apply at least two months prior to the date of travel.\n(2) Package Tour arranged by Registered Travel Agency\n\xa0 \xa0\xa0\xa0\xa0"List of Registered Travel Agency"\n(3)\xa0Business, Conference, Cultural Exchange, etc.\n(4)\xa0Visiting Relatives (within the third degree)\n(5)\xa0Visiting Friends or Distant Relatives\n(6)\xa0Visiting US Military Personnel\n(7)\xa0Spouse/Child of a Japanese National in the Philippines\n(8)\xa0Transit\xa0\n\n2. Multiple-Entry Visa for Temporary Visitor\n*Due to the rapid increase in the number of visitors from the Philippines, examination of visa applications for tourism purposes, may take several weeks\xa0longer than the standard processing time. Therefore, we highly recommend for applicants to please apply at least two months prior to the date of travel.\n(1) Multiple Entry-Visa for a Frequent Traveler\n(2)\xa0MULTIPLE-ENTRY TEMPORARY VISITOR VISA (PHILIPPINE NATIONALS\xa0 WITH CONSIDERABLE FINANCIAL CAPACITY)\u3000\n(3) Multiple Entry-Visa for Business Purpose and Cultural or Intellectual Figures\xa0\n\n3.\xa0Student, Worker, Depedent and Other Status for Long Term Stay\n(1) Student, Worker and Dependent\xa0\n(2) Official*Japan and Republic of the Philippines have the diplomatic visa exemption arrangements for diplomatic passport holders since Oct 1,2024.\n(3) Housekeeper hired by Diplomat/Official\n(4) Medical Stay (including temporary stay)\n(5) Nikkei-Jin (Japanese Descendants)\xa0 \xa0 \xa0 \xa0\n(6)\xa0Filipino Parent travelling to Japan with JFC (Japanese- Filipino Children)\xa0*Please consult with the Embassy in advance.\n\n\n\nVisa Application Documents (download)\n\n1. Basic Documents\n\nVisa Application Form (Example)\nInvitation Letter (Japanese\xa0/ English)\nList of Visa Applicants (Japanese / English)\nItinerary in Japan (Japanese / English)\nLetter of Guarantee (Japanese\xa0/\xa0English)\nDetails of the Company/Organization (Japanese / English)\n\n2. Other Documents\n\nRequest for a Multiple-Entry Visa (Japanese / English)\nVisa Fee Exemption Request\nApplication to Extend Re-entry Permit\n\n3. For Nikkei- Jin Visa (Japanese Descendant)\xa0\n\nFamily Tree (PDF / Excel)\nFamily Photo Sample\n\nRelated Links\n\nVisit Japan Web (to pre-register for airport quarantine, immigration and customs procedures)\nCoronavirus (Ministry of Health, Labor and Welfare of Japan)\nImmigration Services Agency of Japan\nA Daily Life Support Portal for Foreign Nationals\nNew to Japan? Useful Pages for  ...

# %%
import re
import nltk
from nltk.corpus import stopwords

# Download stopwords if you haven't already
nltk.download('stopwords')

# Function to clean text
def clean_text(text):
    # Remove URLs (matches both http://, https:// and other URLs)
    text = re.sub(r'http[s]?://\S+', '', text)

    # Remove dates (matches common formats like '12/01/2021', '2021-12-01', etc.)
    text = re.sub(r'\b(?:\d{1,2}[-/]\d{1,2}[-/]\d{2,4}|\d{4}[-/]\d{1,2}[-/]\d{1,2})\b', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Remove non-alphabetic characters (this keeps only words)
    text = re.sub(r'[^a-z\s]', '', text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = text.split()
    words = [word for word in words if word not in stop_words]

    # Join words back into a single string
    cleaned_text = ' '.join(words)

    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/krimssmirk/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
cleaned_txt = clean_text(raw_txt)

# %%
cleaned_txt = "".join(cleaned_txt)

# %%
tokens = cleaned_txt.split()

# %%
" ".join(tokens[1:len(tokens)])
# Out:
# 'services japanese visa important notice digitization certificate eligibility coe th march japan immigration accepts application digitized coe details please see acceptance photocopy japanese documents th march accept photocopy documents issuedprepared japan instead original details please see advanced procedures customs immigration quarantine th april entrantsreturnees japan need submit valid vaccination certificate negative certificate covid please use visit japan web smooth immigration customs procedures traveling japan apply inquiries concerning visa general information list accredited agencies faqs japan visa extension reentry permit visa fee exemption foreigners visiting three tohoku prefectures types visa requirements choose one visas suitable purpose travel check requirements see important note document submission temporary visitor stay within days maximum tourismdue rapid increase number visitors philippines examination visa applications tourism purposes may take several weeks longer standard processing time therefore highly recommend applicants please apply least two months prior date travel package tour arranged registered travel agency list registered travel agency business conference cultural exchange etc visiting relatives within third degree visiting friends distant relatives visiting us military personnel spousechild japanese national philippines transit multipleentry visa temporary visitor due rapid increase number visitors philippines examination visa applications tourism purposes may take several weeks longer standard processing time therefore highly recommend applicants please apply least two months prior date travel multiple entryvisa frequent traveler multipleentry temporary visitor visa philippine nationals considerable financial capacity multiple entryvisa business purpose cultural intellectual figures student worker depedent status long term stay student worker dependent officialjapan republic philippines diplomatic visa exemption arrangements diplomatic passport holders since oct housekeeper hired diplomatofficial medical stay including temporary stay nikkeijin japanese descendants filipino parent travelling japan jfc japanese filipino children please consult embassy advance visa application documents download basic documents visa application form example invitation letter japanese english list visa applicants japanese english itinerary japan japanese english letter guarantee japanese english details companyorganization japanese english documents request multipleentry visa japanese english visa fee exemption request application extend reentry permit nikkei jin visa japanese descendant family tree pdf excel family photo sample related links visit japan web preregister airport quarantine immigration customs procedures coronavirus ministry health labor welfare japan immigration services agency japan daily life support portal foreign nationals new japan useful pages foreign nationals comprehensive measures acceptance coexistence foreign nationals introductory movies elementary schools japan filipino nice meet lets friendstell elementary school japan recommendation purchase private medical insurance japan tourism agency must bring meat products vegetables fruits japan ministry agriculture forestry fisheries consular services japanese passport requirements downloadable application form available japanese application japanese passports minors pagpapatala ng kapanganakan registration birth marriage japanese philippine nationals nonacceptance request tungkol sa nonacceptance acquisition japanese nationality choice nationality police clearance divorce certificate consular fees including issuance visa passport testimony hague convention convention civil aspects international child abduction philippine department justice bureau immigration memorandum circular guidelines philippine nikkeijin filipino notice postworld war ii remaining japanese nd generation nikkeijin filipino embassy holidays inquiries concerning c ...

# %%
text = []
continuation = []

for i in range(0, len(tokens), 20):
    if i + 20 > len(tokens):
        text.append(" ".join(tokens[i:len(tokens)]))
        continuation.append(" ".join(tokens[len(tokens):]))
    else:
        text.append(" ".join(tokens[i:i+10]))
        continuation.append(" ".join(tokens[i+10:i+20]))

# %% [markdown]
# ## Set Up the Model for Fine-Tuning

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer

# Load pre-trained T5 model and tokenizer
model_name = "t5-small"  # You can use "t5-base" or "t5-large" for better performance
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)

# The tokenizer's pad token is not always set by default
tokenizer.pad_token = tokenizer.eos_token

# %%
# dataset for text continuation (input text + continuation as target)
data = {
    'text': text,
    'continuation': continuation
}

# Load the dataset as a HuggingFace Dataset
dataset = Dataset.from_dict(data)

# %%
# Preprocess the dataset
def preprocess_function(examples):
    # Prepare the inputs for the model (encoder input and decoder output)
    # Use the column names for the text you want to use
    inputs = examples["text"]
    targets = examples["continuation"]
    
    # Tokenize the inputs and targets (add decoder_input_ids by shifting the targets)
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    
    # Add decoder_input_ids
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_datasets = dataset.map(preprocess_function, batched=True)
# Split the dataset into training and validation sets
tokenized_datasets = tokenized_datasets.train_test_split(test_size=0.2)

# Set up training arguments
training_args = TrainingArguments(
    output_dir="./t5-generation",  # where to save the model
    evaluation_strategy="epoch",  # evaluate after each epoch
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=10,
    logging_dir='./logs',
    logging_steps=10,
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
)

# Start the fine-tuning process
trainer.train()
# Out:
# Map: 100%|██████████| 159/159 [00:00<00:00, 1187.35 examples/s]
# /Users/krimssmirk/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='34' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 34/160 30:18 < 1:59:19, 0.02 it/s, Epoch 2.06/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.400400</td>
#       <td>0.718070</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.721100</td>
#       <td>0.674137</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 40
#      32 trainer = Trainer(
#      33     model=model,
#      34     args=training_args,
#      35     train_dataset=tokenized_datasets["train"],
#      36     eval_dataset=tokenized_datasets["test"],
#      37 )
#      39 # Start the fine-tuning process
# ---> 40 trainer.train()
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/transformers/trainer.py:2241, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2239         hf_hub_utils.enable_progress_bars()
#    2240 else:
# -> 2241     return inner_training_loop(
#    2242         args=args,
#    2243         resume_from_checkpoint=resume_from_checkpoint,
#    2244         trial=trial,
#    2245         ignore_keys_for_eval=ignore_keys_for_eval,
#    2246     )
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/transformers/trainer.py:2599, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2595         grad_norm = _grad_norm
#    2597 self.control = self.callback_handler.on_pre_optimizer_step(args, self.state, self.control)
# -> 2599 self.optimizer.step()
#    2601 self.control = self.callback_handler.on_optimizer_step(args, self.state, self.control)
#    2603 if not self.accelerator.optimizer_step_was_skipped:
#    2604     # Delay optimizer scheduling until metrics are generated
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/accelerate/optimizer.py:178, in AcceleratedOptimizer.step(self, closure)
#     176         self._accelerate_step_called = False
#     177     else:
# --> 178         self.optimizer.step(closure)
#     179 if self.accelerator_state.distributed_type == DistributedType.XLA:
#     180     self.gradient_state.is_xla_gradients_synced = False
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:75, in LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      73 instance._step_count += 1
#      74 wrapped = func.__get__(instance, cls)
# ---> 75 return wrapped(*args, **kwargs)
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/torch/optim/optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/torch/optim/adamw.py:187, in AdamW.step(self, closure)
#     174     beta1, beta2 = group["betas"]
#     176     has_complex = self._init_group(
#     177         group,
#     178         params_with_grad,
#    (...)
#     184         state_steps,
#     185     )
# --> 187     adamw(
#     188         params_with_grad,
#     189         grads,
#     190         exp_avgs,
#     191         exp_avg_sqs,
#     192         max_exp_avg_sqs,
#     193         state_steps,
#     194         amsgrad=amsgrad,
#     195         beta1=beta1,
#     196         beta2=beta2,
#     197         lr=group["lr"],
#     198         weight_decay=group["weight_decay"],
#     199         eps=group["eps"],
#     200         maximize=group["maximize"],
#     201         foreach=group["foreach"],
#     202         capturable=group["capturable"],
#     203         differentiable=group["differentiable"],
#     204         fused=group["fused"],
#     205         grad_scale=getattr(self, "grad_scale", None),
#     206         found_inf=getattr(self, "found_inf", None),
#     207         has_complex=has_complex,
#     208     )
#     210 return loss
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/torch/optim/adamw.py:339, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     336 else:
#     337     func = _single_tensor_adamw
# --> 339 func(
#     340     params,
#     341     grads,
#     342     exp_avgs,
#     343     exp_avg_sqs,
#     344     max_exp_avg_sqs,
#     345     state_steps,
#     346     amsgrad=amsgrad,
#     347     beta1=beta1,
#     348     beta2=beta2,
#     349     lr=lr,
#     350     weight_decay=weight_decay,
#     351     eps=eps,
#     352     maximize=maximize,
#     353     capturable=capturable,
#     354     differentiable=differentiable,
#     355     grad_scale=grad_scale,
#     356     found_inf=found_inf,
#     357     has_complex=has_complex,
#     358 )
#
# File ~/Desktop/attic tours projects/3. attic_bot/.venv/lib/python3.11/site-packages/torch/optim/adamw.py:418, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     415 param.mul_(1 - lr * weight_decay)
#     417 # Decay the first and second moment running average coefficient
# --> 418 exp_avg.lerp_(grad, 1 - beta1)
#     419 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     421 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
# Save the model and tokenizer to a specified directory
model_save_path = "./trained_model"
tokenizer_save_path = "./t5_tokenizer"

# Save the trained model
trainer.save_model(model_save_path)

# Save the tokenizer
tokenizer.save_pretrained(tokenizer_save_path)

print("Model and tokenizer saved!")
# Out:
# Model and tokenizer saved!
